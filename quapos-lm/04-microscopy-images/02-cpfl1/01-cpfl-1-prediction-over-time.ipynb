# %% [markdown]
# ## Prediction of Cpfl1 timecourse
#
# The notebook aims to show predicted images from the Cpfl1 timelaps for the following ages: p08, P14, P20, P30, P70, and P245.
#
# The intensity images should be shown in the first row, corresponding predictions in the second row. The resulting images will be used in figure 3 of the paper.
#
# Additionally, a function was written which computes an image with a scale bar, and can be overlayed on top of the actual image using `plt.subplots()`.

# %%
import apoc
import matplotlib.pyplot as plt
import numpy as np
import pyclesperanto_prototype as cle

import sys
sys.path.append("../../")
from quapos_lm import scale_bar_image, predict_image

# %%
# Load classifier
quapos_lm = apoc.ObjectSegmenter(opencl_filename = "../../01-training-and-validation/02-quapos-lm.cl")
quapos_lm.feature_importances()
# Out:
# {'gaussian_blur=1': 0.32557488170342097,
#  'difference_of_gaussian=1': 0.4231073391932076,
#  'laplace_box_of_gaussian_blur=1': 0.25131777910337144}

# %% [markdown]
# The following representative images are now used to predict and visualise the image:
#
# - `C2-cpfl-p08-3.3-20x-flo.tif`
# - `C2-cpfl-p14-3.3-20x-flo.tif`
# - `C2-cpfl-p20-3.3-20x-flo.tif`
# - `C2-cpfl-p30-3.4-20x-flo.tif`
# - `C2-cpfl-p70-2.4-20x-flo.tif`
# - `C2-cpfl-w35-1.3-20x-flo.tif`

# %%
# Define path where data is stored
images = "../../data/02-data-for-pixel-classifier/cpfl-wt-comparison/a-s-opsin-images/"

# Define path where images should be stored
save_path = "../../plots-images/quapos-paper/figure-3-images/"

# %% [markdown]
# ### Predict masks from the images
#
# Now the images will be loaded one after another, the masks predicted, and visualised. Addtionally, the first image will be used to define a scale bar. Since the microscope and objective for all images was the same the same scale bar can be applied to all images.
#
# Only a crop of the image and prediction will be shown.
#
# #### Image P08

# %%
# Open image
image_p08 = cle.imread(images + "C2-cpfl-p08-3.3-20x-flo.tif")

# predict the image
prediction_p08 = predict_image(image=image_p08, classifier=quapos_lm)

# Compute scale bar of the crop
scale_bar, cmap = scale_bar_image(image=image_p08[15, 450:650, 200:400],
                                  micron_length=0.323,
                                  scale_length=25)

# %%
# Define subplots and figure size
fig, axs = plt.subplots(2, 1, figsize=(5, 10))

# Show the intensity image
cle.imshow(image_p08[..., 450:650, 200:400], plot=axs[0])

# Add scale bar to intensity image
cle.imshow(scale_bar, plot=axs[0], colormap=cmap)

# Remove ticks and labels from the image
axs[0].tick_params(left=False,
                right=False,
                labelleft=False,
                labelbottom=False, 
                bottom=False)
    
# Show the corresponding prediction
cle.imshow(prediction_p08[..., 450:650, 200:400], plot = axs[1], labels = True)
axs[1].tick_params(left = False,
                right = False,
                labelleft = False,
                labelbottom = False, 
                bottom = False)

# Adjust the space between the images
plt.subplots_adjust(hspace=0.03)

plt.savefig(save_path + "01-a-prediction-p08.png",
            dpi=300,
            bbox_inches="tight")
# Out:
# 3 3 lens
# 3 3 lens

# %% [markdown]
# #### Image P14

# %%
# Open image
image_p14 = cle.imread(images + "C2-cpfl-p14-3.3-20x-flo.tif")

# predict the image
prediction_p14 = predict_image(image=image_p14, classifier=quapos_lm)

# %%
# Define subplots and figure size
fig, axs = plt.subplots(2, 1, figsize=(5, 10))

# Show the intensity image
cle.imshow(image_p14[..., 540:740, 200:400], plot=axs[0])

# Add scale bar to intensity image
cle.imshow(scale_bar, plot=axs[0], colormap=cmap)

# Remove ticks and labels from the image
axs[0].tick_params(left=False,
                right=False,
                labelleft=False,
                labelbottom=False, 
                bottom=False)
    
# Show the corresponding prediction
cle.imshow(prediction_p14[..., 540:740, 200:400], plot=axs[1], labels=True)
axs[1].tick_params(left = False,
                right = False,
                labelleft = False,
                labelbottom = False, 
                bottom = False)

# Adjust the space between the images
plt.subplots_adjust(hspace=0.03)

plt.savefig(save_path + "01-b-prediction-p14.png",
            dpi=300,
            bbox_inches="tight")
# Out:
# 3 3 lens
# 3 3 lens

# %% [markdown]
# #### Image P20

# %%
# Open image
image_p20 = cle.imread(images + "C2-cpfl-p20-3.3-20x-flo.tif")

# predict the image
prediction_p20 = predict_image(image=image_p20, classifier=quapos_lm)

# %%
# Define subplots and figure size
fig, axs = plt.subplots(2, 1, figsize=(5, 10))

# Show the intensity image
cle.imshow(image_p20[..., 550:750, 200:400], plot=axs[0])

# Add scale bar to intensity image
cle.imshow(scale_bar, plot=axs[0], colormap=cmap)

# Remove ticks and labels from the image
axs[0].tick_params(left=False,
                right=False,
                labelleft=False,
                labelbottom=False, 
                bottom=False)
    
# Show the corresponding prediction
cle.imshow(prediction_p20[..., 550:750, 200:400], plot=axs[1], labels=True)
axs[1].tick_params(left = False,
                right = False,
                labelleft = False,
                labelbottom = False, 
                bottom = False)

# Adjust the space between the images
plt.subplots_adjust(hspace=0.03)

plt.savefig(save_path + "01-c-prediction-p20.png",
            dpi=300,
            bbox_inches="tight")
# Out:
# 3 3 lens
# 3 3 lens

# %% [markdown]
# #### Image P30

# %%
# Open image
image_p30 = cle.imread(images + "C2-cpfl-p30-3.4-20x-flo.tif")

# predict the image
prediction_p30 = predict_image(image=image_p30, classifier=quapos_lm)

# %%
# Define subplots and figure size
fig, axs = plt.subplots(2, 1, figsize=(5, 10))

# Show the intensity image
cle.imshow(image_p30[..., 500:700, 700:900], plot=axs[0])

# Add scale bar to intensity image
cle.imshow(scale_bar, plot=axs[0], colormap=cmap)

# Remove ticks and labels from the image
axs[0].tick_params(left=False,
                right=False,
                labelleft=False,
                labelbottom=False, 
                bottom=False)
    
# Show the corresponding prediction
cle.imshow(prediction_p30[..., 500:700, 700:900], plot=axs[1], labels=True)
axs[1].tick_params(left = False,
                right = False,
                labelleft = False,
                labelbottom = False, 
                bottom = False)

# Adjust the space between the images
plt.subplots_adjust(hspace=0.03)

plt.savefig(save_path + "01-d-prediction-p30.png",
            dpi=300,
            bbox_inches="tight")
# Out:
# 3 3 lens
# 3 3 lens

# %% [markdown]
# #### Image P70

# %%
# Open image
image_p70 = cle.imread(images + "C2-cpfl-p70-2.4-20x-flo.tif")

# predict the image
prediction_p70 = predict_image(image=image_p70, classifier=quapos_lm)

# %%
# Define subplots and figure size
fig, axs = plt.subplots(2, 1, figsize=(5, 10))

# Show the intensity image
cle.imshow(image_p70[..., 480:680, 100:300], plot=axs[0])

# Add scale bar to intensity image
cle.imshow(scale_bar, plot=axs[0], colormap=cmap)

# Remove ticks and labels from the image
axs[0].tick_params(left=False,
                right=False,
                labelleft=False,
                labelbottom=False, 
                bottom=False)
    
# Show the corresponding prediction
cle.imshow(prediction_p70[..., 480:680, 100:300], plot=axs[1], labels=True)
axs[1].tick_params(left = False,
                right = False,
                labelleft = False,
                labelbottom = False, 
                bottom = False)

# Adjust the space between the images
plt.subplots_adjust(hspace=0.03)

plt.savefig(save_path + "01-e-prediction-p70.png",
            dpi=300,
            bbox_inches="tight")
# Out:
# 3 3 lens
# 3 3 lens

# %% [markdown]
# #### Image P245

# %%
# Open image
image_p245 = cle.imread(images + "C2-cpfl-p70-2.4-20x-flo.tif")

# predict the image
prediction_p245 = predict_image(image=image_p245, classifier=quapos_lm)

# %%
# Define subplots and figure size
fig, axs = plt.subplots(2, 1, figsize=(5, 10))

# Show the intensity image
cle.imshow(image_p245[..., 490:690, 450:650], plot=axs[0])

# Add scale bar to intensity image
cle.imshow(scale_bar, plot=axs[0], colormap=cmap)

# Remove ticks and labels from the image
axs[0].tick_params(left=False,
                right=False,
                labelleft=False,
                labelbottom=False, 
                bottom=False)
    
# Show the corresponding prediction
cle.imshow(prediction_p245[..., 490:690, 450:650], plot=axs[1], labels=True)
axs[1].tick_params(left = False,
                right = False,
                labelleft = False,
                labelbottom = False, 
                bottom = False)

# Adjust the space between the images
plt.subplots_adjust(hspace=0.03)

plt.savefig(save_path + "01-e-prediction-p245.png",
            dpi=300,
            bbox_inches="tight")
# Out:
# 3 3 lens
# 3 3 lens
