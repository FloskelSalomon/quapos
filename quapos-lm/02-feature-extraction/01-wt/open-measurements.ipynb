# %%
import numpy as np
import pandas as pd

# %%
path = "../../measurements/wt-postnatal-development/"

# %% [markdown]
# ### Simpleitk measurements

# %%
measurements = pd.read_csv(path + "01-a-feature-extraction-simpleitk.csv")
measurements
# Out:
#        label  maximum        mean      median  minimum       sigma       sum  \
# 0          1    803.0  314.092437  282.884766    186.0   99.098496  261639.0
# 1          2   1845.0  620.114058  466.576172    174.0  407.194822  467566.0
# 2          3    564.0  274.831858  253.494141    154.0   91.856545   62112.0
# 3          4    540.0  285.008439  268.189453    153.0   89.769054   67547.0
# 4          5    264.0  234.200000  238.798828    202.0   20.192821    5855.0
# ...      ...      ...         ...         ...      ...         ...       ...
# 18703    174    685.0  346.677288  326.101562    187.0   92.460071  424333.0
# 18704    175    609.0  337.340530  326.101562    188.0   81.507414  343750.0
# 18705    176    347.0  255.431818  252.820312    193.0   37.513655   11239.0
# 18706    177    345.0  247.479915  245.492188    176.0   32.455513  117058.0
# 18707    178    307.0  281.000000  282.132812    246.0   22.020193    2810.0
#
# ...

# %% [markdown]
# ### Porespy measurements

# %%
measurements = pd.read_csv(path + "01-b-feature-extraction-porespy.csv")
measurements
# Out:
#        label  surface_area  volume  bbox_volume  convex_volume  sphericity  \
# 0          1    820.528198   833.0         3456           1525    0.521780
# 1          2    417.350677   754.0         1254            865    0.959910
# 2          3    209.240112   226.0          416            274    0.857521
# 3          4    227.670990   237.0          480            284    0.813471
# 4          5     80.413963    25.0           72             33    0.514177
# ...      ...           ...     ...          ...            ...         ...
# 18703    174   1265.061035  1224.0         6732           3094    0.437415
# 18704    175    978.182373  1019.0         5250           2200    0.500626
# 18705    176     70.511078    44.0           90             54    0.854795
# 18706    177    638.787354   473.0         3465           1333    0.459588
# 18707    178      6.928203    10.0           10              0    3.239889
#
# ...

# %% [markdown]
# ### Combined Measurements

# %%
measurements = pd.read_csv(path + "02-measurements-concatenated.csv")
measurements
# Out:
#        label  maximum        mean      median  minimum       sigma       sum  \
# 0          1    803.0  314.092437  282.884766    186.0   99.098496  261639.0
# 1          2   1845.0  620.114058  466.576172    174.0  407.194822  467566.0
# 2          3    564.0  274.831858  253.494141    154.0   91.856545   62112.0
# 3          4    540.0  285.008439  268.189453    153.0   89.769054   67547.0
# 4          5    264.0  234.200000  238.798828    202.0   20.192821    5855.0
# ...      ...      ...         ...         ...      ...         ...       ...
# 18703    174    685.0  346.677288  326.101562    187.0   92.460071  424333.0
# 18704    175    609.0  337.340530  326.101562    188.0   81.507414  343750.0
# 18705    176    347.0  255.431818  252.820312    193.0   37.513655   11239.0
# 18706    177    345.0  247.479915  245.492188    176.0   32.455513  117058.0
# 18707    178    307.0  281.000000  282.132812    246.0   22.020193    2810.0
#
# ...

# %% [markdown]
# ### Relevant Features

# %%
measurements = pd.read_csv(path + "03-relevant-features.csv")
measurements
# Out:
#        label  maximum        mean      median  minimum       sigma       sum  \
# 0          1    803.0  314.092437  282.884766    186.0   99.098496  261639.0
# 1          2   1845.0  620.114058  466.576172    174.0  407.194822  467566.0
# 2          3    564.0  274.831858  253.494141    154.0   91.856545   62112.0
# 3          4    540.0  285.008439  268.189453    153.0   89.769054   67547.0
# 4          5    264.0  234.200000  238.798828    202.0   20.192821    5855.0
# ...      ...      ...         ...         ...      ...         ...       ...
# 18703    174    685.0  346.677288  326.101562    187.0   92.460071  424333.0
# 18704    175    609.0  337.340530  326.101562    188.0   81.507414  343750.0
# 18705    176    347.0  255.431818  252.820312    193.0   37.513655   11239.0
# 18706    177    345.0  247.479915  245.492188    176.0   32.455513  117058.0
# 18707    178    307.0  281.000000  282.132812    246.0   22.020193    2810.0
#
# ...

# %% [markdown]
# ### Measurements rescaled

# %%
measurements = pd.read_csv(path + "04-measurements-rescaled.csv")
measurements
# Out:
#        label  age  biol_repl  image_id  maximum        mean      median  \
# 0          1    8          1         0    803.0  314.092437  282.884766
# 1          2    8          1         0   1845.0  620.114058  466.576172
# 2          3    8          1         0    564.0  274.831858  253.494141
# 3          4    8          1         0    540.0  285.008439  268.189453
# 4          5    8          1         0    264.0  234.200000  238.798828
# ...      ...  ...        ...       ...      ...         ...         ...
# 18703    174   24         28        83    685.0  346.677288  326.101562
# 18704    175   24         28        83    609.0  337.340530  326.101562
# 18705    176   24         28        83    347.0  255.431818  252.820312
# 18706    177   24         28        83    345.0  247.479915  245.492188
# 18707    178   24         28        83    307.0  281.000000  282.132812
#
#        minimum       sigma       sum  ...  \
# 0        186.0   99.098496  261639.0  ...
# ...

# %% [markdown]
# ### Inf reduced measurements

# %%
measurements = pd.read_csv(path + "05-a-measurements-inf-reduced.csv")
measurements
# Out:
#        label  age  biol_repl  image_id  maximum        mean      median  \
# 0          1    8          1         0    803.0  314.092437  282.884766
# 1          2    8          1         0   1845.0  620.114058  466.576172
# 2          3    8          1         0    564.0  274.831858  253.494141
# 3          4    8          1         0    540.0  285.008439  268.189453
# 4          5    8          1         0    264.0  234.200000  238.798828
# ...      ...  ...        ...       ...      ...         ...         ...
# 16695    173   24         28        83    312.0  243.290323  245.492188
# 16696    174   24         28        83    685.0  346.677288  326.101562
# 16697    175   24         28        83    609.0  337.340530  326.101562
# 16698    176   24         28        83    347.0  255.431818  252.820312
# 16699    177   24         28        83    345.0  247.479915  245.492188
#
#        minimum       sigma       sum  ...  \
# 0        186.0   99.098496  261639.0  ...
# ...

# %% [markdown]
# ### Measurements 5 percentile

# %%
measurements = pd.read_csv(path + "05-b-measurements-filtered-5-percentile.csv")
measurements
# Out:
#        label  age  biol_repl  image_id  maximum        mean      median  \
# 0          1    8          1         0    803.0  314.092437  282.884766
# 1          2    8          1         0   1845.0  620.114058  466.576172
# 2          3    8          1         0    564.0  274.831858  253.494141
# 3          4    8          1         0    540.0  285.008439  268.189453
# 4          5    8          1         0    264.0  234.200000  238.798828
# ...      ...  ...        ...       ...      ...         ...         ...
# 15731    173   24         28        83    312.0  243.290323  245.492188
# 15732    174   24         28        83    685.0  346.677288  326.101562
# 15733    175   24         28        83    609.0  337.340530  326.101562
# 15734    176   24         28        83    347.0  255.431818  252.820312
# 15735    177   24         28        83    345.0  247.479915  245.492188
#
#        minimum       sigma       sum  ...  \
# 0        186.0   99.098496  261639.0  ...
# ...

# %% [markdown]
# ### Complete filtered

# %%
measurements = pd.read_csv(path + "05-c-measurements-filtered.csv")
measurements
# Out:
#        label  age  biol_repl  image_id  maximum        mean      median  \
# 0          1    8          1         0    803.0  314.092437  282.884766
# 1          2    8          1         0   1845.0  620.114058  466.576172
# 2          3    8          1         0    564.0  274.831858  253.494141
# 3          4    8          1         0    540.0  285.008439  268.189453
# 4          5    8          1         0    264.0  234.200000  238.798828
# ...      ...  ...        ...       ...      ...         ...         ...
# 14896    173   24         28        83    312.0  243.290323  245.492188
# 14897    174   24         28        83    685.0  346.677288  326.101562
# 14898    175   24         28        83    609.0  337.340530  326.101562
# 14899    176   24         28        83    347.0  255.431818  252.820312
# 14900    177   24         28        83    345.0  247.479915  245.492188
#
#        minimum       sigma       sum  ...  \
# 0        186.0   99.098496  261639.0  ...
# ...

# %% [markdown]
# ### Averaged correlation matrix

# %%
measurements = pd.read_csv(path + "06-means-for-correlation.csv")
measurements
# Out:
#     biol_repl       label   age     maximum        mean      median  \
# 0           1   83.000000   8.0  572.072487  276.999939  253.902252
# 1           2   74.333333   8.0  642.001611  293.921538  264.767499
# 2           3   83.000000   8.0  623.870848  291.964848  263.895176
# 3           4   85.666667   8.0  510.612076  233.010028  210.645494
# 4           5  146.333333  10.0  426.188669  223.960324  207.407505
# 5           6  166.666667  10.0  444.097340  234.782142  217.308213
# 6           7  214.333333  10.0  296.683127  156.582861  145.243371
# 7           8  203.000000  12.0  708.948804  327.162766  294.613773
# 8           9  199.333333  12.0  802.868097  351.689919  312.281348
# 9          10  159.666667  12.0  367.077671  200.070006  186.465406
# 10         11  202.666667  12.0  283.327005  144.763113  133.383258
# 11         12  159.000000  12.0  373.074739  201.701977  188.151470
# 12         13  254.666667  14.0  759.902537  342.489714  307.303742
# ...

# %% [markdown]
# ### Renamed

# %%
measurements = pd.read_csv(path + "07-renamed-for-correlation.csv")
measurements
# Out:
#     biol_repl      number   age  max_intensity  mean_intensity  \
# 0           1   83.000000   8.0     572.072487      276.999939
# 1           2   74.333333   8.0     642.001611      293.921538
# 2           3   83.000000   8.0     623.870848      291.964848
# 3           4   85.666667   8.0     510.612076      233.010028
# 4           5  146.333333  10.0     426.188669      223.960324
# 5           6  166.666667  10.0     444.097340      234.782142
# 6           7  214.333333  10.0     296.683127      156.582861
# 7           8  203.000000  12.0     708.948804      327.162766
# 8           9  199.333333  12.0     802.868097      351.689919
# 9          10  159.666667  12.0     367.077671      200.070006
# 10         11  202.666667  12.0     283.327005      144.763113
# 11         12  159.000000  12.0     373.074739      201.701977
# 12         13  254.666667  14.0     759.902537      342.489714
# 13         14  214.000000  14.0     761.346170      350.579059
# ...
