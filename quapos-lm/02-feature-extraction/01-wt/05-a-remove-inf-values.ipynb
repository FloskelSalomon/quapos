# %% [markdown]
# ## Data filtering - inf values
#
# The feature extraction with porespy added under certain cases inf values for some 3D measurements (sphericity or convex volume). It is expected, that the classifier still segments smaller particles in 2D. When porespy tries to extract a 3D feature from a 2D label the inf value is returned.
#
# Since these inf values could harm the downstream analysis process, they will be removed here.

# %%
import numpy as np
import pandas as pd

# %%
# Define path were measurements are stored
path = "../../measurements/wt-postnatal-development/"

# %%
# Load the measurements
measurements = pd.read_csv(path + "04-measurements-rescaled.csv")
measurements
# Out:
#        label  age  biol_repl  image_id  maximum        mean      median  \
# 0          1    8          1         0    803.0  314.092437  282.884766
# 1          2    8          1         0   1845.0  620.114058  466.576172
# 2          3    8          1         0    564.0  274.831858  253.494141
# 3          4    8          1         0    540.0  285.008439  268.189453
# 4          5    8          1         0    264.0  234.200000  238.798828
# ...      ...  ...        ...       ...      ...         ...         ...
# 18703    174   24         28        83    685.0  346.677288  326.101562
# 18704    175   24         28        83    609.0  337.340530  326.101562
# 18705    176   24         28        83    347.0  255.431818  252.820312
# 18706    177   24         28        83    345.0  247.479915  245.492188
# 18707    178   24         28        83    307.0  281.000000  282.132812
#
#        minimum       sigma       sum  ...  \
# 0        186.0   99.098496  261639.0  ...
# 1        174.0  407.194822  467566.0  ...
# 2        154.0   91.856545   62112.0  ...
# 3        153.0   89.769054   67547.0  ...
# 4        202.0   20.192821    5855.0  ...
# ...        ...         ...       ...  ...
# 18703    187.0   92.460071  424333.0  ...
# 18704    188.0   81.507414  343750.0  ...
# 18705    193.0   37.513655   11239.0  ...
# 18706    176.0   32.455513  117058.0  ...
# 18707    246.0   22.020193    2810.0  ...
#
#        equivalent_spherical_perimeter_rescaled  \
# 0                                   138.287624
# 1                                   129.399980
# 2                                    57.955182
# 3                                    59.820799
# 4                                    13.355085
# ...                                        ...
# 18703                               178.734172
# 18704                               158.174366
# 18705                                19.468019
# 18706                                94.825995
# 18707                                 7.250256
#
#        equivalent_spherical_radius_rescaled  feret_diameter_rescaled  \
# 0                                  1.885333                 8.107236
# 1                                  1.823742                 6.111447
# 2                                  1.220513                 3.995289
# 3                                  1.240002                 4.669557
# 4                                  0.585895                 2.261000
# ...                                     ...                      ...
# 18703                              2.143385                 8.551879
# 18704                              2.016343                 8.478365
# 18705                              0.707387                 1.910894
# 18706                              1.561205                 7.951313
# 18707                              0.431691                 1.331763
#
#        perimeter_2d_rescaled  major_axis_length_2d_rescaled  \
# 0                  18.460443                       8.872033
# 1                   8.976538                       3.444867
# 2                   6.273068                       2.549953
# 3                   6.273068                       2.766553
# 4                   2.777771                       1.010003
# ...                      ...                            ...
# 18703              30.066147                       8.226779
# 18704              21.955740                       9.303697
# 18705               4.002664                       1.622372
# 18706              19.177968                       9.110146
# 18707               1.478576                       0.646000
#
#        minor_axis_length_2d_rescaled  surface_area_rescaled  \
# 0                           2.037236              85.604886
# 1                           2.044837              43.541779
# 2                           1.312964              21.829812
# 3                           1.117553              23.752687
# 4                           0.745937               8.389508
# ...                              ...                    ...
# 18703                       5.176775             131.982553
# 18704                       3.873424             102.052789
# 18705                       0.810159               7.356350
# 18706                       2.632142              66.644046
# 18707                       0.000000               0.722813
#
#        bbox_volume_rescaled  convex_volume_rescaled  volume_rescaled
# 0                116.461211               51.389857        28.070656
# 1                 42.257627               29.149001        25.408493
# 2                 14.018479                9.233325         7.615808
# 3                 16.175168                9.570308         7.986489
# 4                  2.426275                1.112043         0.842457
# ...                     ...                     ...              ...
# 18703            226.856733              104.262438        41.246679
# 18704            176.915902               74.136187        34.338534
# 18705              3.032844                1.819706         1.482724
# 18706            116.764495               44.919790        15.939280
# 18707              0.336983                0.000000         0.336983
#
# [18708 rows x 31 columns]

# %% [markdown]
# ### Identify inf values
#
# Check if there are inf values in the dataframe and how many rows contain inf values.

# %%
# Check for inf values
np.isinf(measurements.values).any()
# Out:
# True

# %%
# Check how many rows contain inf values
(measurements.isin([np.inf, -np.inf])).any(axis=1).sum()
# Out:
# 2008

# %% [markdown]
# ### Remove inf values from the dataframe

# %%
# Remove inf values
measurements_without_inf = measurements[~measurements.isin([np.inf, -np.inf]).any(axis=1)]
measurements_without_inf
# Out:
#        label  age  biol_repl  image_id  maximum        mean      median  \
# 0          1    8          1         0    803.0  314.092437  282.884766
# 1          2    8          1         0   1845.0  620.114058  466.576172
# 2          3    8          1         0    564.0  274.831858  253.494141
# 3          4    8          1         0    540.0  285.008439  268.189453
# 4          5    8          1         0    264.0  234.200000  238.798828
# ...      ...  ...        ...       ...      ...         ...         ...
# 18702    173   24         28        83    312.0  243.290323  245.492188
# 18703    174   24         28        83    685.0  346.677288  326.101562
# 18704    175   24         28        83    609.0  337.340530  326.101562
# 18705    176   24         28        83    347.0  255.431818  252.820312
# 18706    177   24         28        83    345.0  247.479915  245.492188
#
#        minimum       sigma       sum  ...  \
# 0        186.0   99.098496  261639.0  ...
# 1        174.0  407.194822  467566.0  ...
# 2        154.0   91.856545   62112.0  ...
# 3        153.0   89.769054   67547.0  ...
# 4        202.0   20.192821    5855.0  ...
# ...        ...         ...       ...  ...
# 18702    179.0   26.596939   60336.0  ...
# 18703    187.0   92.460071  424333.0  ...
# 18704    188.0   81.507414  343750.0  ...
# 18705    193.0   37.513655   11239.0  ...
# 18706    176.0   32.455513  117058.0  ...
#
#        equivalent_spherical_perimeter_rescaled  \
# 0                                   138.287624
# 1                                   129.399980
# 2                                    57.955182
# 3                                    59.820799
# 4                                    13.355085
# ...                                        ...
# 18702                                61.657763
# 18703                               178.734172
# 18704                               158.174366
# 18705                                19.468019
# 18706                                94.825995
#
#        equivalent_spherical_radius_rescaled  feret_diameter_rescaled  \
# 0                                  1.885333                 8.107236
# 1                                  1.823742                 6.111447
# 2                                  1.220513                 3.995289
# 3                                  1.240002                 4.669557
# 4                                  0.585895                 2.261000
# ...                                     ...                      ...
# 18702                              1.258897                 5.297594
# 18703                              2.143385                 8.551879
# 18704                              2.016343                 8.478365
# 18705                              0.707387                 1.910894
# 18706                              1.561205                 7.951313
#
#        perimeter_2d_rescaled  major_axis_length_2d_rescaled  \
# 0                  18.460443                       8.872033
# 1                   8.976538                       3.444867
# 2                   6.273068                       2.549953
# 3                   6.273068                       2.766553
# 4                   2.777771                       1.010003
# ...                      ...                            ...
# 18702               9.737588                       4.460800
# 18703              30.066147                       8.226779
# 18704              21.955740                       9.303697
# 18705               4.002664                       1.622372
# 18706              19.177968                       9.110146
#
#        minor_axis_length_2d_rescaled  surface_area_rescaled  \
# 0                           2.037236              85.604886
# 1                           2.044837              43.541779
# 2                           1.312964              21.829812
# 3                           1.117553              23.752687
# 4                           0.745937               8.389508
# ...                              ...                    ...
# 18702                       1.451807              40.056207
# 18703                       5.176775             131.982553
# 18704                       3.873424             102.052789
# 18705                       0.810159               7.356350
# 18706                       2.632142              66.644046
#
#        bbox_volume_rescaled  convex_volume_rescaled  volume_rescaled
# 0                116.461211               51.389857        28.070656
# 1                 42.257627               29.149001        25.408493
# 2                 14.018479                9.233325         7.615808
# 3                 16.175168                9.570308         7.986489
# 4                  2.426275                1.112043         0.842457
# ...                     ...                     ...              ...
# 18702             46.705798               12.805341         8.357170
# 18703            226.856733              104.262438        41.246679
# 18704            176.915902               74.136187        34.338534
# 18705              3.032844                1.819706         1.482724
# 18706            116.764495               44.919790        15.939280
#
# [16700 rows x 31 columns]

# %%
# Any infs left?
np.isinf(measurements_without_inf.values).any()
# Out:
# False

# %%
measurements_without_inf.to_csv(path + "05-a-measurements-inf-reduced.csv", index = False)
