# %% [markdown]
# ## Rescale size features
#
# The dataframe contains different size parameters, which require to be rescaled into their actual micrometer values from pixels/voxels.

# %%
import numpy as np
import pandas as pd

# %%
# Define path with measurements
path = "../../measurements/cpfl/"

# %%
# Load the measurements
measurements = pd.read_csv(path + "03-features-cpfl-inf-reduced.csv")
measurements.keys()
# Out:
# Index(['label', 'maximum', 'mean', 'median', 'minimum', 'sigma', 'sum',
#        'variance', 'bbox_3', 'bbox_4', 'bbox_5', 'elongation',
#        'feret_diameter', 'flatness', 'equivalent_ellipsoid_diameter_0',
#        'equivalent_ellipsoid_diameter_1', 'equivalent_ellipsoid_diameter_2',
#        'equivalent_spherical_perimeter', 'equivalent_spherical_radius',
#        'volume', 'surface_area', 'bbox_volume', 'convex_volume', 'sphericity',
#        'solidity', 'perimeter_2d', 'major_axis_length_2d',
#        'minor_axis_length_2d', 'age', 'image_id', 'genotype'],
#       dtype='object')

# %% [markdown]
# ### Rescaling of 1D features
#
# Features which only have 1 dimension are recalculated by multypling them with 0.323.

# %%
# Define 1D features
features_1d = ['bbox_3', 'bbox_4', 'bbox_5', 'equivalent_ellipsoid_diameter_0',
       'equivalent_ellipsoid_diameter_1', 'equivalent_ellipsoid_diameter_2',
       'equivalent_spherical_perimeter', 'equivalent_spherical_radius', 'feret_diameter', 'perimeter_2d', 'major_axis_length_2d',
       'minor_axis_length_2d']

# %%
# Apply recalculation for all features
for feature in features_1d:
    
    # Multiply them by 0.323
    measurements[feature + "_rescaled"] = measurements[feature] * 0.323
    
measurements
# Out:
#       label  maximum        mean      median  minimum       sigma        sum  \
# 0         1    250.0  189.793103  184.144531    157.0   20.305487     5504.0
# 1         2    334.0  207.273684  202.871094    133.0   42.706679    19691.0
# 2         4    262.0  214.904762  215.355469    175.0   27.285353     4513.0
# 3         5    311.0  195.171429  190.386719    118.0   36.997206     6831.0
# 4         6    355.0  219.354167  215.355469    147.0   47.335750    21058.0
# ...     ...      ...         ...         ...      ...         ...        ...
# 5845    176    437.0  228.476298  219.855469    118.0   59.914239   101215.0
# 5846    177   1542.0  485.858939  412.605469    137.0  265.029227  1043625.0
# 5847    178    416.0  224.548673  213.832031    127.0   62.839505    25374.0
# 5848    180    481.0  251.469466  237.925781    145.0   64.019970    65885.0
# 5849    181    289.0  198.567568  195.761719    131.0   37.774051    14694.0
#
#           variance  bbox_3  bbox_4  ...  bbox_5_rescaled  \
# 0       412.312808       3       3  ...            1.615
# 1      1823.860470       3       6  ...            2.584
# 2       744.490476       3       3  ...            1.615
# 3      1368.793277       4       3  ...            1.938
# 4      2240.673246       5       6  ...            1.938
# ...            ...     ...     ...  ...              ...
# 5845   3589.716066      14      13  ...            2.907
# 5846  70240.491038      29      22  ...            4.522
# 5847   3948.803413       6       6  ...            2.261
# 5848   4098.556535       7      15  ...            3.230
# 5849   1426.878934       3       6  ...            2.261
#
#       equivalent_ellipsoid_diameter_0_rescaled  \
# 0                                     0.917910
# 1                                     1.079846
# 2                                     0.811317
# 3                                     0.928015
# 4                                     1.503206
# ...                                        ...
# 5845                                  1.635678
# 5846                                  3.281107
# 5847                                  1.599834
# 5848                                  1.762742
# 5849                                  1.099786
#
#       equivalent_ellipsoid_diameter_1_rescaled  \
# 0                                     1.030668
# 1                                     2.149595
# 2                                     0.900066
# 3                                     1.129874
# 4                                     1.921640
# ...                                        ...
# 5845                                  2.864352
# 5846                                  6.034325
# 5847                                  1.830251
# 5848                                  2.445258
# 5849                                  1.847189
#
#       equivalent_ellipsoid_diameter_2_rescaled  \
# 0                                     1.972821
# 1                                     2.633988
# 2                                     1.850817
# 3                                     2.148286
# 4                                     2.138896
# ...                                        ...
# 5845                                  6.085392
# 5846                                  6.982229
# 5847                                  2.483716
# 5848                                  3.911981
# 5849                                  2.344344
#
#       equivalent_spherical_perimeter_rescaled  \
# 0                                   14.744113
# 1                                   32.521386
# 2                                   11.889571
# 3                                   16.713421
# 4                                   32.749208
# ...                                       ...
# 5845                                90.772814
# 5846                               260.041601
# 5847                                36.509477
# 5848                                63.956915
# 5849                                27.532213
#
#       equivalent_spherical_radius_rescaled  feret_diameter_rescaled  \
# 0                                 0.615610                 1.480172
# 1                                 0.914283                 2.624064
# 2                                 0.552814                 1.370373
# 3                                 0.655434                 1.678357
# 4                                 0.917480                 2.068209
# ...                                    ...                      ...
# 5845                              1.527475                 5.732681
# 5846                              2.585340                 9.158631
# 5847                              0.968722                 2.261000
# 5848                              1.282154                 4.579315
# 5849                              0.841234                 2.093279
#
#       perimeter_2d_rescaled  major_axis_length_2d_rescaled  \
# 0                  2.957153                       0.976660
# 1                  4.973873                       2.127172
# 2                  2.957153                       0.976660
# 3                  3.390218                       1.255098
# 4                  5.481241                       1.910113
# ...                     ...                            ...
# 5845              13.307188                       6.005873
# 5846              32.454379                       8.011704
# 5847               5.734924                       1.901773
# 5848              13.771030                       4.629315
# 5849               4.794492                       1.926136
#
#       minor_axis_length_2d_rescaled
# 0                          0.904212
# 1                          1.027014
# 2                          0.904212
# 3                          0.902928
# 4                          1.514661
# ...                             ...
# 5845                       1.731845
# 5846                       7.033195
# 5847                       1.715924
# 5848                       2.203200
# 5849                       1.040501
#
# [5850 rows x 43 columns]

# %% [markdown]
# ### Rescaled 2D feature
#
# There is 1 feature which is 2D (surface area). It is recalculated into actual pixel values by multiplication with $0.323^2$

# %%
# Rescale the surface area, multiply by 0.323^2
measurements["surface_area_rescaled"] = measurements["surface_area"] * np.power(0.323, 2)
measurements
# Out:
#       label  maximum        mean      median  minimum       sigma        sum  \
# 0         1    250.0  189.793103  184.144531    157.0   20.305487     5504.0
# 1         2    334.0  207.273684  202.871094    133.0   42.706679    19691.0
# 2         4    262.0  214.904762  215.355469    175.0   27.285353     4513.0
# 3         5    311.0  195.171429  190.386719    118.0   36.997206     6831.0
# 4         6    355.0  219.354167  215.355469    147.0   47.335750    21058.0
# ...     ...      ...         ...         ...      ...         ...        ...
# 5845    176    437.0  228.476298  219.855469    118.0   59.914239   101215.0
# 5846    177   1542.0  485.858939  412.605469    137.0  265.029227  1043625.0
# 5847    178    416.0  224.548673  213.832031    127.0   62.839505    25374.0
# 5848    180    481.0  251.469466  237.925781    145.0   64.019970    65885.0
# 5849    181    289.0  198.567568  195.761719    131.0   37.774051    14694.0
#
#           variance  bbox_3  bbox_4  ...  \
# 0       412.312808       3       3  ...
# 1      1823.860470       3       6  ...
# 2       744.490476       3       3  ...
# 3      1368.793277       4       3  ...
# 4      2240.673246       5       6  ...
# ...            ...     ...     ...  ...
# 5845   3589.716066      14      13  ...
# 5846  70240.491038      29      22  ...
# 5847   3948.803413       6       6  ...
# 5848   4098.556535       7      15  ...
# 5849   1426.878934       3       6  ...
#
#       equivalent_ellipsoid_diameter_0_rescaled  \
# 0                                     0.917910
# 1                                     1.079846
# 2                                     0.811317
# 3                                     0.928015
# 4                                     1.503206
# ...                                        ...
# 5845                                  1.635678
# 5846                                  3.281107
# 5847                                  1.599834
# 5848                                  1.762742
# 5849                                  1.099786
#
#       equivalent_ellipsoid_diameter_1_rescaled  \
# 0                                     1.030668
# 1                                     2.149595
# 2                                     0.900066
# 3                                     1.129874
# 4                                     1.921640
# ...                                        ...
# 5845                                  2.864352
# 5846                                  6.034325
# 5847                                  1.830251
# 5848                                  2.445258
# 5849                                  1.847189
#
#       equivalent_ellipsoid_diameter_2_rescaled  \
# 0                                     1.972821
# 1                                     2.633988
# 2                                     1.850817
# 3                                     2.148286
# 4                                     2.138896
# ...                                        ...
# 5845                                  6.085392
# 5846                                  6.982229
# 5847                                  2.483716
# 5848                                  3.911981
# 5849                                  2.344344
#
#       equivalent_spherical_perimeter_rescaled  \
# 0                                   14.744113
# 1                                   32.521386
# 2                                   11.889571
# 3                                   16.713421
# 4                                   32.749208
# ...                                       ...
# 5845                                90.772814
# 5846                               260.041601
# 5847                                36.509477
# 5848                                63.956915
# 5849                                27.532213
#
#       equivalent_spherical_radius_rescaled  feret_diameter_rescaled  \
# 0                                 0.615610                 1.480172
# 1                                 0.914283                 2.624064
# 2                                 0.552814                 1.370373
# 3                                 0.655434                 1.678357
# 4                                 0.917480                 2.068209
# ...                                    ...                      ...
# 5845                              1.527475                 5.732681
# 5846                              2.585340                 9.158631
# 5847                              0.968722                 2.261000
# 5848                              1.282154                 4.579315
# 5849                              0.841234                 2.093279
#
#       perimeter_2d_rescaled  major_axis_length_2d_rescaled  \
# 0                  2.957153                       0.976660
# 1                  4.973873                       2.127172
# 2                  2.957153                       0.976660
# 3                  3.390218                       1.255098
# 4                  5.481241                       1.910113
# ...                     ...                            ...
# 5845              13.307188                       6.005873
# 5846              32.454379                       8.011704
# 5847               5.734924                       1.901773
# 5848              13.771030                       4.629315
# 5849               4.794492                       1.926136
#
#       minor_axis_length_2d_rescaled  surface_area_rescaled
# 0                          0.904212               3.881768
# 1                          1.027014               7.095704
# 2                          0.904212               5.174290
# 3                          0.902928               7.379101
# 4                          1.514661              11.022045
# ...                             ...                    ...
# 5845                       1.731845              45.719796
# 5846                       7.033195             160.768595
# 5847                       1.715924              15.687029
# 5848                       2.203200              35.317111
# 5849                       1.040501               8.369222
#
# [5850 rows x 44 columns]

# %% [markdown]
# ### Rescale 3D features
#
# Certain features are 3 dimensional. They are rescaled by multiplying them with $0.323^3$.

# %%
# Define 3D features
features_3d = ['bbox_volume', 'convex_volume', 'volume']

# %%
# Apply for loop to rescale those features
for feature in features_3d:
    
    # Rescale and add "_rescaled" to the name of the columns
    measurements[feature + "_rescaled"] = measurements[feature] * np.power(0.323, 3)
    
measurements
# Out:
#       label  maximum        mean      median  minimum       sigma        sum  \
# 0         1    250.0  189.793103  184.144531    157.0   20.305487     5504.0
# 1         2    334.0  207.273684  202.871094    133.0   42.706679    19691.0
# 2         4    262.0  214.904762  215.355469    175.0   27.285353     4513.0
# 3         5    311.0  195.171429  190.386719    118.0   36.997206     6831.0
# 4         6    355.0  219.354167  215.355469    147.0   47.335750    21058.0
# ...     ...      ...         ...         ...      ...         ...        ...
# 5845    176    437.0  228.476298  219.855469    118.0   59.914239   101215.0
# 5846    177   1542.0  485.858939  412.605469    137.0  265.029227  1043625.0
# 5847    178    416.0  224.548673  213.832031    127.0   62.839505    25374.0
# 5848    180    481.0  251.469466  237.925781    145.0   64.019970    65885.0
# 5849    181    289.0  198.567568  195.761719    131.0   37.774051    14694.0
#
#           variance  bbox_3  bbox_4  ...  \
# 0       412.312808       3       3  ...
# 1      1823.860470       3       6  ...
# 2       744.490476       3       3  ...
# 3      1368.793277       4       3  ...
# 4      2240.673246       5       6  ...
# ...            ...     ...     ...  ...
# 5845   3589.716066      14      13  ...
# 5846  70240.491038      29      22  ...
# 5847   3948.803413       6       6  ...
# 5848   4098.556535       7      15  ...
# 5849   1426.878934       3       6  ...
#
#       equivalent_spherical_perimeter_rescaled  \
# 0                                   14.744113
# 1                                   32.521386
# 2                                   11.889571
# 3                                   16.713421
# 4                                   32.749208
# ...                                       ...
# 5845                                90.772814
# 5846                               260.041601
# 5847                                36.509477
# 5848                                63.956915
# 5849                                27.532213
#
#       equivalent_spherical_radius_rescaled  feret_diameter_rescaled  \
# 0                                 0.615610                 1.480172
# 1                                 0.914283                 2.624064
# 2                                 0.552814                 1.370373
# 3                                 0.655434                 1.678357
# 4                                 0.917480                 2.068209
# ...                                    ...                      ...
# 5845                              1.527475                 5.732681
# 5846                              2.585340                 9.158631
# 5847                              0.968722                 2.261000
# 5848                              1.282154                 4.579315
# 5849                              0.841234                 2.093279
#
#       perimeter_2d_rescaled  major_axis_length_2d_rescaled  \
# 0                  2.957153                       0.976660
# 1                  4.973873                       2.127172
# 2                  2.957153                       0.976660
# 3                  3.390218                       1.255098
# 4                  5.481241                       1.910113
# ...                     ...                            ...
# 5845              13.307188                       6.005873
# 5846              32.454379                       8.011704
# 5847               5.734924                       1.901773
# 5848              13.771030                       4.629315
# 5849               4.794492                       1.926136
#
#       minor_axis_length_2d_rescaled  surface_area_rescaled  \
# 0                          0.904212               3.881768
# 1                          1.027014               7.095704
# 2                          0.904212               5.174290
# 3                          0.902928               7.379101
# 4                          1.514661              11.022045
# ...                             ...                    ...
# 5845                       1.731845              45.719796
# 5846                       7.033195             160.768595
# 5847                       1.715924              15.687029
# 5848                       2.203200              35.317111
# 5849                       1.040501               8.369222
#
#       bbox_volume_rescaled  convex_volume_rescaled  volume_rescaled
# 0                 1.516422                1.078345         0.977250
# 1                 4.852550                3.572016         3.201335
# 2                 1.516422                0.943551         0.707664
# 3                 2.426275                1.381629         1.179439
# 4                 6.065688                3.774206         3.235034
# ...                    ...                     ...              ...
# 5845             55.197761               20.994020        14.928332
# 5846            300.992921              132.366793        72.383878
# 5847              8.491963                4.414473         3.807904
# 5848             35.383180               15.063125         8.828946
# 5849              4.245982                2.931749         2.493672
#
# [5850 rows x 47 columns]

# %% [markdown]
# ### Filter duplicated features
#
# All rescaled features are now duplicated. Non-rescaled size features will be removed.

# %%
# Keep only rescaled features
measurements_rescaled = measurements[['label', 'age', 'image_id', 'genotype', 'maximum', 'mean', 'median', 'minimum', 'sigma', 'sum',
       'variance', 'flatness', 'elongation','sphericity', 'solidity', 'bbox_3_rescaled', 'bbox_4_rescaled', 'bbox_5_rescaled',
       'equivalent_ellipsoid_diameter_0_rescaled',
       'equivalent_ellipsoid_diameter_1_rescaled',
       'equivalent_ellipsoid_diameter_2_rescaled',
       'equivalent_spherical_perimeter_rescaled',
       'equivalent_spherical_radius_rescaled', 'feret_diameter_rescaled',
       'perimeter_2d_rescaled', 'major_axis_length_2d_rescaled',
       'minor_axis_length_2d_rescaled', 'surface_area_rescaled',
       'bbox_volume_rescaled', 'convex_volume_rescaled', 'volume_rescaled']]
measurements_rescaled
# Out:
#       label  age  image_id genotype  maximum        mean      median  minimum  \
# 0         1    8         0     cpfl    250.0  189.793103  184.144531    157.0
# 1         2    8         0     cpfl    334.0  207.273684  202.871094    133.0
# 2         4    8         0     cpfl    262.0  214.904762  215.355469    175.0
# 3         5    8         0     cpfl    311.0  195.171429  190.386719    118.0
# 4         6    8         0     cpfl    355.0  219.354167  215.355469    147.0
# ...     ...  ...       ...      ...      ...         ...         ...      ...
# 5845    176   70        39       wt    437.0  228.476298  219.855469    118.0
# 5846    177   70        39       wt   1542.0  485.858939  412.605469    137.0
# 5847    178   70        39       wt    416.0  224.548673  213.832031    127.0
# 5848    180   70        39       wt    481.0  251.469466  237.925781    145.0
# 5849    181   70        39       wt    289.0  198.567568  195.761719    131.0
#
#            sigma        sum  ...  equivalent_spherical_perimeter_rescaled  \
# 0      20.305487     5504.0  ...                                14.744113
# 1      42.706679    19691.0  ...                                32.521386
# 2      27.285353     4513.0  ...                                11.889571
# 3      36.997206     6831.0  ...                                16.713421
# 4      47.335750    21058.0  ...                                32.749208
# ...          ...        ...  ...                                      ...
# 5845   59.914239   101215.0  ...                                90.772814
# 5846  265.029227  1043625.0  ...                               260.041601
# 5847   62.839505    25374.0  ...                                36.509477
# 5848   64.019970    65885.0  ...                                63.956915
# 5849   37.774051    14694.0  ...                                27.532213
#
#       equivalent_spherical_radius_rescaled  feret_diameter_rescaled  \
# 0                                 0.615610                 1.480172
# 1                                 0.914283                 2.624064
# 2                                 0.552814                 1.370373
# 3                                 0.655434                 1.678357
# 4                                 0.917480                 2.068209
# ...                                    ...                      ...
# 5845                              1.527475                 5.732681
# 5846                              2.585340                 9.158631
# 5847                              0.968722                 2.261000
# 5848                              1.282154                 4.579315
# 5849                              0.841234                 2.093279
#
#       perimeter_2d_rescaled  major_axis_length_2d_rescaled  \
# 0                  2.957153                       0.976660
# 1                  4.973873                       2.127172
# 2                  2.957153                       0.976660
# 3                  3.390218                       1.255098
# 4                  5.481241                       1.910113
# ...                     ...                            ...
# 5845              13.307188                       6.005873
# 5846              32.454379                       8.011704
# 5847               5.734924                       1.901773
# 5848              13.771030                       4.629315
# 5849               4.794492                       1.926136
#
#       minor_axis_length_2d_rescaled  surface_area_rescaled  \
# 0                          0.904212               3.881768
# 1                          1.027014               7.095704
# 2                          0.904212               5.174290
# 3                          0.902928               7.379101
# 4                          1.514661              11.022045
# ...                             ...                    ...
# 5845                       1.731845              45.719796
# 5846                       7.033195             160.768595
# 5847                       1.715924              15.687029
# 5848                       2.203200              35.317111
# 5849                       1.040501               8.369222
#
#       bbox_volume_rescaled  convex_volume_rescaled  volume_rescaled
# 0                 1.516422                1.078345         0.977250
# 1                 4.852550                3.572016         3.201335
# 2                 1.516422                0.943551         0.707664
# 3                 2.426275                1.381629         1.179439
# 4                 6.065688                3.774206         3.235034
# ...                    ...                     ...              ...
# 5845             55.197761               20.994020        14.928332
# 5846            300.992921              132.366793        72.383878
# 5847              8.491963                4.414473         3.807904
# 5848             35.383180               15.063125         8.828946
# 5849              4.245982                2.931749         2.493672
#
# [5850 rows x 31 columns]

# %%
measurements_rescaled.to_csv(path + "04-measurements-rescaled.csv", index=False)
