# %% [markdown]
# ## Boxplot of the sphericity
#
# Additionally, it might be interesting to investigate the raw unaveraged data. Here, a boxplot of the sphericity will be computed were all datapoints are pooled.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Define path were measurements are stored
stats_path = "../../measurements/wt-postnatal-development/"

# Define path were measurements should be stored
save_path = "../../plots-images/quapos-paper/sup-fig-3-plots/"

# %%
# Load measurements
measurements = pd.read_csv(stats_path + "05-b-measurements-filtered.csv")
measurements
# Out:
#        label  age  biol_repl  image_id  maximum        mean      median  \
# 0          1    8          1         0    803.0  314.092437  282.884766
# 1          2    8          1         0   1845.0  620.114058  466.576172
# 2          3    8          1         0    564.0  274.831858  253.494141
# 3          4    8          1         0    540.0  285.008439  268.189453
# 4          5    8          1         0    264.0  234.200000  238.798828
# ...      ...  ...        ...       ...      ...         ...         ...
# 14896    173   24         28        83    312.0  243.290323  245.492188
# 14897    174   24         28        83    685.0  346.677288  326.101562
# 14898    175   24         28        83    609.0  337.340530  326.101562
# 14899    176   24         28        83    347.0  255.431818  252.820312
# 14900    177   24         28        83    345.0  247.479915  245.492188
#
#        minimum       sigma       sum  ...  \
# 0        186.0   99.098496  261639.0  ...
# ...

# %% [markdown]
# ### Compute the boxplot

# %%
# Create boxplot
boxplot = sns.boxplot(data=measurements,
                            x="age",
                            y="sphericity",
                            hue="age",
                            legend=False,
                            palette="deep")

# Adjust y axis
plt.yticks(fontsize=12)
plt.ylabel("OS sphericity", fontsize=14)

# Adjust x axis
plt.xticks(fontsize=12)
plt.xlabel("Postnatal age in days", fontsize=14)

plt.savefig(save_path + "04-b-boxplot-sphericity.png",
            dpi=300,
            bbox_inches="tight")
