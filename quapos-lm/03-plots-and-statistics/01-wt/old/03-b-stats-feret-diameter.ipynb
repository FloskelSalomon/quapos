# %% [markdown]
# ## Tukey test for feret diameter over time

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.stats.multicomp as mc

# %%
stats_path = "../measurements/wt-postnatal-development/"

# %%
measurements = pd.read_csv(stats_path + "05-c-measurements_filtered-5-and-95-percentile.csv")
measurements
# Out:
#        label  age  biol_repl  image_id  maximum        mean      median  \
# 0          1    8          1         0    803.0  314.092437  282.884766
# 1          2    8          1         0   1845.0  620.114058  466.576172
# 2          3    8          1         0    564.0  274.831858  253.494141
# 3          4    8          1         0    540.0  285.008439  268.189453
# 4          5    8          1         0    264.0  234.200000  238.798828
# ...      ...  ...        ...       ...      ...         ...         ...
# 14896    173   24         28        83    312.0  243.290323  245.492188
# 14897    174   24         28        83    685.0  346.677288  326.101562
# 14898    175   24         28        83    609.0  337.340530  326.101562
# 14899    176   24         28        83    347.0  255.431818  252.820312
# 14900    177   24         28        83    345.0  247.479915  245.492188
#
#        minimum       sigma       sum  ...  \
# 0        186.0   99.098496  261639.0  ...
# ...

# %%
feret_diameter = measurements.groupby("image_id", as_index=False)["feret_diameter_rescaled", "age", "biol_repl"].mean()
feret_diameter
# Out:
# C:\Users\fsalo\AppData\Local\Temp\ipykernel_24808\3603211815.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   feret_diameter = measurements.groupby("image_id", as_index=False)["feret_diameter_rescaled", "age", "biol_repl"].mean()
#     image_id  feret_diameter_rescaled   age  biol_repl
# 0          0                 4.376663   8.0        1.0
# 1          1                 3.668398   8.0        1.0
# 2          2                 3.756347   8.0        1.0
# 3          3                 4.843015   8.0        2.0
# 4          4                 4.105999   8.0        2.0
# ..       ...                      ...   ...        ...
# 79        79                 4.187781  24.0       27.0
# 80        80                 4.061732  24.0       27.0
# 81        81                 4.725444  24.0       28.0
# 82        82                 5.359738  24.0       28.0
# ...

# %%
feret_diameter_mean = feret_diameter.groupby("biol_repl", as_index=False)["feret_diameter_rescaled", "age"].mean()
feret_diameter_mean
# Out:
# C:\Users\fsalo\AppData\Local\Temp\ipykernel_24808\4159093406.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   feret_diameter_mean = feret_diameter.groupby("biol_repl", as_index=False)["feret_diameter_rescaled", "age"].mean()
#     biol_repl  feret_diameter_rescaled   age
# 0         1.0                 3.933802   8.0
# 1         2.0                 4.117962   8.0
# 2         3.0                 4.040329   8.0
# 3         4.0                 4.137301   8.0
# 4         5.0                 3.286424  10.0
# 5         6.0                 3.279710  10.0
# 6         7.0                 3.374919  10.0
# 7         8.0                 3.803847  12.0
# 8         9.0                 3.807037  12.0
# 9        10.0                 3.372486  12.0
# 10       11.0                 3.559255  12.0
# 11       12.0                 3.299990  12.0
# 12       13.0                 4.490888  14.0
# ...

# %%
#import custom functions
import sys
sys.path.append("../../../../../01_python_definitions")
from fluorescent_microscopy_analysis import tukey_test

# %%
f, p, tukey = tukey_test(feret_diameter_mean, feature="feret_diameter_rescaled")
tukey
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
