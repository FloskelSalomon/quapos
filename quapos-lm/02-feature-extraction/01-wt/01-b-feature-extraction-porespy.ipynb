# %% [markdown]
# ## Feature extraction postnatal development - porespy
#
# The workflow to demonstrate the feature extraction with the function `regionprops_3D` from `porespy` was already demonstrated [here]().
#
# This notebook aims to extract the same features from all images of the postnatal development with a for loop.

# %%
import apoc
import numpy as np
import os
import pandas as pd
import pyclesperanto_prototype as cle

from porespy.metrics import regionprops_3D
from skimage.measure import regionprops_table

import sys
sys.path.append("../..")
from quapos_lm import rescale_image, rescale_segmentation, predict_image

# %%
# Load classifier
quapos_lm = apoc.ObjectSegmenter(opencl_filename = "../../01-training-and-validation/02-quapos-lm.cl")
quapos_lm.feature_importances()
# Out:
# {'gaussian_blur=1': 0.32557488170342097,
#  'difference_of_gaussian=1': 0.4231073391932076,
#  'laplace_box_of_gaussian_blur=1': 0.25131777910337144}

# %%
# Define directory for images
images = "../../data/02-data-for-pixel-classifier/statistics-data/"

# Define file list
file_list = os.listdir(images)

# Show file list
print(file_list)
# Out:
# ['C1-p08-20x-zoom-1.2-replicate-1.tif', 'C1-p08-20x-zoom-1.5-replicate-1.tif', 'C1-p08-20x-zoom-1.7-replicate-1.tif', 'C1-p08-20x-zoom-2.2-replicate-2.tif', 'C1-p08-20x-zoom-2.5-replicate-2.tif', 'C1-p08-20x-zoom-2.7-replicate-2.tif', 'C1-p08-20x-zoom-3.2-replicate-3.tif', 'C1-p08-20x-zoom-3.5-replicate-3.tif', 'C1-p08-20x-zoom-3.7-replicate-3.tif', 'C1-p08-20x-zoom-4.2-replicate-4.tif', 'C1-p08-20x-zoom-4.5-replicate-4.tif', 'C1-p08-20x-zoom-4.7-replicate-4.tif', 'C1-p10-20x-zoom-1.1-suse-replicate-5.tif', 'C1-p10-20x-zoom-1.3-suse-replicate-5.tif', 'C1-p10-20x-zoom-1.4-suse-replicate-5.tif', 'C1-p10-20x-zoom-2.2-suse-replicate-6.tif', 'C1-p10-20x-zoom-2.3-suse-replicate-6.tif', 'C1-p10-20x-zoom-2.5-suse-replicate-6.tif', 'C1-p10-20x-zoom-3.1-suse-replicate-7.tif', 'C1-p10-20x-zoom-3.3-suse-replicate-7.tif', 'C1-p10-20x-zoom-3.5-suse-replicate-7.tif', 'C1-p12-20x-zoom-flo-1.4-replicate-8.tif', 'C1-p12-20x-zoom-flo-1.5-replicate-8.tif', 'C1-p12-20x-zoom-flo-1.7-replicate-8.tif', 'C1-p12-20x-zoom-flo-2.4-replicate-9.tif', 'C1-p12-20x-zoom-flo-2.6-replicate-9.tif', 'C1-p12-20x-zoom-flo-2.7-replicate-9.tif', 'C1-p12-20x-zoom-suse-1.1-replicate-10.tif', 'C1-p12-20x-zoom-suse-1.3-replicate-10.tif', 'C1-p12-20x-zoom-suse-1.5-replicate-10.tif', 'C1-p12-20x-zoom-suse-2.1-replicate-11.tif', 'C1-p12-20x-zoom-suse-2.3-replicate-11.tif', 'C1-p12-20x-zoom-suse-2.5-replicate-11.tif', 'C1-p12-20x-zoom-suse-3.1-replicate-12.tif', 'C1-p12-20x-zoom-suse-3.3-replicate-12.tif', 'C1-p12-20x-zoom-suse-3.4-replicate-12.tif', 'C1-p14-20x-zoom-1.2-replicate-13.tif', 'C1-p14-20x-zoom-1.4-replicate-13.tif', 'C1-p14-20x-zoom-1.6-replicate-13.tif', 'C1-p14-20x-zoom-2.2-replicate-14.tif', 'C1-p14-20x-zoom-2.4-replicate-14.tif', 'C1-p14-20x-zoom-2.6-replicate-14.tif', 'C1-p14-20x-zoom-3.2-replicate-15.tif', 'C1-p14-20x-zoom-3.4-replicate-15.tif', 'C1-p14-20x-zoom-3.7-replicate-15.tif', 'C1-p14-20x-zoom-4.2-replicate-16.tif', 'C1-p14-20x-zoom-4.5-replicate-16.tif', 'C1-p14-20x-zoom-4.7-replicate-16.tif', 'C1-p16-20x-zoom-flo-1.2-replicate-17.tif', 'C1-p16-20x-zoom-flo-1.5-replicate-17.tif', 'C1-p16-20x-zoom-flo-1.7-replicate-17.tif', 'C1-p16-20x-zoom-flo-2.2-replicate-18.tif', 'C1-p16-20x-zoom-flo-2.5-replicate-18.tif', 'C1-p16-20x-zoom-flo-2.7-replicate-18.tif', 'C1-p16-20x-zoom-suse-1.2-replicate-19.tif', 'C1-p16-20x-zoom-suse-1.5-replicate-19.tif', 'C1-p16-20x-zoom-suse-1.6-replicate-19.tif', 'C1-p16-20x-zoom-suse-2.2-replicate-20.tif', 'C1-p16-20x-zoom-suse-2.5-replicate-20.tif', 'C1-p16-20x-zoom-suse-2.6-replicate-20.tif', 'C1-p20-20x-zoom-flo-1.2-replicate-21.tif', 'C1-p20-20x-zoom-flo-1.4-replicate-21.tif', 'C1-p20-20x-zoom-flo-1.6-replicate-21.tif', 'C1-p20-20x-zoom-flo-2.2-replicate-22.tif', 'C1-p20-20x-zoom-flo-2.4-replicate-22.tif', 'C1-p20-20x-zoom-flo-2.7-replicate-22.tif', 'C1-p20-20x-zoom-suse-1.2-replicate-23.tif', 'C1-p20-20x-zoom-suse-1.5-replicate-23.tif', 'C1-p20-20x-zoom-suse-1.6-replicate-23.tif', 'C1-p20-20x-zoom-suse-2.2-replicate-24.tif', 'C1-p20-20x-zoom-suse-2.3-replicate-24.tif', 'C1-p20-20x-zoom-suse-2.5-replicate-24.tif', 'C1-p24-20x-zoom-1.2-replicate-25.tif', 'C1-p24-20x-zoom-1.4-replicate-25.tif', 'C1-p24-20x-zoom-1.6-replicate-25.tif', 'C1-p24-20x-zoom-2.2-replicate-26.tif', 'C1-p24-20x-zoom-2.4-replicate-26.tif', 'C1-p24-20x-zoom-2.6-replicate-26.tif', 'C1-p24-20x-zoom-3.2-replicate-27.tif', 'C1-p24-20x-zoom-3.4-replicate-27.tif', 'C1-p24-20x-zoom-3.6-replicate-27.tif', 'C1-p24-20x-zoom-4.2-replicate-28.tif', 'C1-p24-20x-zoom-4.4-replicate-28.tif', 'C1-p24-20x-zoom-4.6-replicate-28.tif']

# %% [markdown]
# ### Extract features
#
# Now a for loop will be computed to extract all the features.

# %%
# Define array to store extracted features
features_porespy = []

# Loop over the image folder and extract all the features
for i, file_name in enumerate(file_list):
    
    # Load image
    image = imread(images + file_name)
    
    # Predict the image
    prediction = predict_image(image=image, classifier=quapos_lm)
    
    # Rescale the image
    image_rescaled = rescale_image(image=image, voxel_x=0.323, voxel_y=0.323, voxel_z=0.490)
    
    # Rescale the prediction
    prediction_rescaled = rescale_segmentation(segmentation=prediction, voxel_x=0.323, voxel_y=0.323, voxel_z=0.490)
        
    # Feature extraction with porespy regionprops_3D
    features_i = regionprops_3D(prediction_rescaled)
    
    # Define empty array to store features of current image
    extracted_features = []
    
    # Loop over the extracted features to obtain features in accessible data table
    for prop in features_i:
        
        # Obtain some features
        label = prop.label
        surface_area = prop.surface_area
        volume = prop.volume
        bbox_volume = prop.bbox_volume
        convex_volume = prop.convex_volume
        sphericity = prop.sphericity
        solidity = prop.solidity
        
        # Obtain the predicted label in its bounding box, flatten it into 2D and obtain more features
        mask = prop.mask
        mask = cle.maximum_z_projection(mask)
        mask = cle.connected_components_labeling_diamond(mask)
        
        # From 2D label major axis length retrieved
        major_axis_length = regionprops_table(
            label_image = mask,
            properties = ["axis_major_length"])
        major_axis_length = major_axis_length["axis_major_length"][0]
        
        # Minor axis length retrieved
        minor_axis_length = regionprops_table(
            label_image = mask,
            properties = ["axis_minor_length"])
        minor_axis_length = minor_axis_length["axis_minor_length"][0]
        
        # Crofton perimeter retrieved
        perimeter_crofton = regionprops_table(
            label_image = mask,
            properties = ["perimeter_crofton"])
        perimeter_crofton = perimeter_crofton["perimeter_crofton"][0]
        
        # Define names for the different variables
        measurements_dict = {"label": label,
                             "surface_area": surface_area,
                             "volume": volume,
                             "bbox_volume": bbox_volume,
                             "convex_volume": convex_volume,
                             "sphericity": sphericity,
                             "solidity": solidity,
                             "perimeter_2d": perimeter_crofton,
                             "major_axis_length_2d": major_axis_length,
                             "minor_axis_length_2d": minor_axis_length}
        
        # Add features of current image into dataframe
        extracted_features.append(measurements_dict)
    
    # Turn features of current image into a pandas dataframe
    extracted_features = pd.DataFrame(extracted_features)
    
    # Add features of current image into final dataframe
    features_porespy.append(extracted_features)
# Out:
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768502921  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(3) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768502921  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768519728  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  4  Error-roundoff 4.3e-15  _one-merge 3e-14  _near-inside 1.5e-13
#   Visible-distance 8.5e-15  U-max-coplanar 8.5e-15  Width-outside 1.7e-14
#   _wide-facet 5.1e-14  _maxoutside 3.4e-14
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v4):     1     0     0
# - p3(v3):     2     0     1
# - p5(v2):     4     0     1
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.3e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     1.75        0      0.5
#
# facet p3 p5 p0 distance=    0
# facet p1 p5 p0 distance=    0
# facet p1 p3 p0 distance=    0
# facet p1 p3 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         4  difference=    4
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.3e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768536535  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  2  Error-roundoff 2.5e-15  _one-merge 1.7e-14
#   _near-inside 8.6e-14  Visible-distance 4.9e-15  U-max-coplanar 4.9e-15
#   Width-outside 9.8e-15  _wide-facet 3e-14  _maxoutside 2e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p2(v4):     1     0     0
# - p1(v3):     0     1     0
# - p4(v2):     2     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.5e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     0.75     0.25        0
#
# facet p1 p4 p0 distance=    0
# facet p2 p4 p0 distance= -0.25
# facet p2 p1 p0 distance=    0
# facet p2 p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         2  difference=    2
#   1:         0         1  difference=    1
#   2:         0         0  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.5e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768570149  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768586956  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  1  Error-roundoff 1.4e-15  _one-merge 9.7e-15
#   _near-inside 4.9e-14  Visible-distance 2.8e-15  U-max-coplanar 2.8e-15
#   Width-outside 5.5e-15  _wide-facet 1.7e-14  _maxoutside 1.1e-14
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p3(v4):     1     0     1
# - p1(v3):     0     0     1
# - p2(v2):     1     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 1.4e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point      0.5        0      0.5
#
# facet p1 p2 p0 distance=    0
# facet p3 p2 p0 distance=    0
# facet p3 p1 p0 distance=    0
# facet p3 p1 p2 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         1  difference=    1
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 1.4e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768586956  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  6  Error-roundoff 8.3e-15  _one-merge 5.8e-14
#   _near-inside 2.9e-13  Visible-distance 1.7e-14  U-max-coplanar 1.7e-14
#   Width-outside 3.3e-14  _wide-facet 1e-13  _maxoutside 6.7e-14
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p4(v4):     1     0     6
# - p9(v3):     3     0     0
# - p30(v2):     6     0     0
# - p0(v1):     0     0     5
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.3e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point      2.5        0     2.75
#
# facet p9 p30 p0 distance=    0
# facet p4 p30 p0 distance=    0
# facet p4 p9 p0 distance=    0
# facet p4 p9 p30 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         6  difference=    6
#   1:         0         0  difference=    0
#   2:         0         6  difference=    6
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.3e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768620570  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(3) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768637377  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768637377  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  2  Error-roundoff 2.5e-15  _one-merge 1.7e-14
#   _near-inside 8.6e-14  Visible-distance 4.9e-15  U-max-coplanar 4.9e-15
#   Width-outside 9.8e-15  _wide-facet 3e-14  _maxoutside 2e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p2(v4):     1     0     0
# - p1(v3):     0     1     0
# - p4(v2):     2     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.5e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     0.75     0.25        0
#
# facet p1 p4 p0 distance=    0
# facet p2 p4 p0 distance= -0.25
# facet p2 p1 p0 distance=    0
# facet p2 p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         2  difference=    2
#   1:         0         1  difference=    1
#   2:         0         0  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.5e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768654184  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768687798  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  3  Error-roundoff 4e-15  _one-merge 2.8e-14  _near-inside 1.4e-13
#   Visible-distance 8.1e-15  U-max-coplanar 8.1e-15  Width-outside 1.6e-14
#   _wide-facet 4.8e-14  _maxoutside 3.2e-14
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p3(v4):     1     0     2
# - p1(v3):     1     0     0
# - p7(v2):     3     0     1
# - p0(v1):     0     0     1
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     1.25        0        1
#
# facet p1 p7 p0 distance=    0
# facet p3 p7 p0 distance=    0
# facet p3 p1 p0 distance=    0
# facet p3 p1 p7 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         3  difference=    3
#   1:         0         0  difference=    0
#   2:         0         2  difference=    2
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768704605  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768738219  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768738219  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768755026  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  2  Error-roundoff 2.5e-15  _one-merge 1.7e-14
#   _near-inside 8.6e-14  Visible-distance 4.9e-15  U-max-coplanar 4.9e-15
#   Width-outside 9.8e-15  _wide-facet 3e-14  _maxoutside 2e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p2(v4):     1     0     0
# - p1(v3):     0     0     1
# - p4(v2):     2     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.5e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     0.75        0     0.25
#
# facet p1 p4 p0 distance=    0
# facet p2 p4 p0 distance=    0
# facet p2 p1 p0 distance=    0
# facet p2 p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         2  difference=    2
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.5e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768755026  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768771833  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768805447  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768839061  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  2  Error-roundoff 2.5e-15  _one-merge 1.7e-14
#   _near-inside 8.6e-14  Visible-distance 4.9e-15  U-max-coplanar 4.9e-15
#   Width-outside 9.8e-15  _wide-facet 3e-14  _maxoutside 2e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p2(v4):     1     0     0
# - p1(v3):     0     0     1
# - p3(v2):     2     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.5e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     0.75        0     0.25
#
# facet p1 p3 p0 distance=    0
# facet p2 p3 p0 distance=    0
# facet p2 p1 p0 distance=    0
# facet p2 p1 p3 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         2  difference=    2
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.5e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768872675  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  2  Error-roundoff 2.5e-15  _one-merge 1.7e-14
#   _near-inside 8.6e-14  Visible-distance 4.9e-15  U-max-coplanar 4.9e-15
#   Width-outside 9.8e-15  _wide-facet 3e-14  _maxoutside 2e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p3(v4):     2     0     1
# - p1(v3):     1     0     1
# - p2(v2):     2     0     0
# - p0(v1):     0     0     1
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.5e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     1.25        0     0.75
#
# facet p1 p2 p0 distance=    0
# facet p3 p2 p0 distance=    0
# facet p3 p1 p0 distance=    0
# facet p3 p1 p2 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         2  difference=    2
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.5e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768872675  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  4  Error-roundoff 4.9e-15  _one-merge 3.4e-14
#   _near-inside 1.7e-13  Visible-distance 9.8e-15  U-max-coplanar 9.8e-15
#   Width-outside 2e-14  _wide-facet 5.9e-14  _maxoutside 3.9e-14
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v4):     0     0     2
# - p4(v3):     2     0     0
# - p9(v2):     4     0     1
# - p0(v1):     0     0     1
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.9e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point      1.5        0        1
#
# facet p4 p9 p0 distance=    0
# facet p1 p9 p0 distance=    0
# facet p1 p4 p0 distance=    0
# facet p1 p4 p9 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         4  difference=    4
#   1:         0         0  difference=    0
#   2:         0         2  difference=    2
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.9e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(3) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768889482  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768889482  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  3  Error-roundoff 3.4e-15  _one-merge 2.4e-14
#   _near-inside 1.2e-13  Visible-distance 6.7e-15  U-max-coplanar 6.7e-15
#   Width-outside 1.3e-14  _wide-facet 4e-14  _maxoutside 2.7e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v4):     1     0     0
# - p2(v3):     1     0     1
# - p5(v2):     3     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.4e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     1.25        0     0.25
#
# facet p2 p5 p0 distance=    0
# facet p1 p5 p0 distance=    0
# facet p1 p2 p0 distance=    0
# facet p1 p2 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         3  difference=    3
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.4e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768906289  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  4  Error-roundoff 4.3e-15  _one-merge 3e-14  _near-inside 1.5e-13
#   Visible-distance 8.5e-15  U-max-coplanar 8.5e-15  Width-outside 1.7e-14
#   _wide-facet 5.1e-14  _maxoutside 3.4e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p2(v4):     1     0     0
# - p1(v3):     0     0     1
# - p8(v2):     4     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.3e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     1.25        0     0.25
#
# facet p1 p8 p0 distance=    0
# facet p2 p8 p0 distance=    0
# facet p2 p1 p0 distance=    0
# facet p2 p1 p8 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         4  difference=    4
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.3e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768906289  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  2  Error-roundoff 2.5e-15  _one-merge 1.7e-14
#   _near-inside 8.6e-14  Visible-distance 4.9e-15  U-max-coplanar 4.9e-15
#   Width-outside 9.8e-15  _wide-facet 3e-14  _maxoutside 2e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p2(v4):     1     0     0
# - p1(v3):     0     0     1
# - p4(v2):     2     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.5e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     0.75        0     0.25
#
# facet p1 p4 p0 distance=    0
# facet p2 p4 p0 distance=    0
# facet p2 p1 p0 distance=    0
# facet p2 p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         2  difference=    2
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.5e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768906289  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768906289  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  3  Error-roundoff 3.4e-15  _one-merge 2.4e-14
#   _near-inside 1.2e-13  Visible-distance 6.7e-15  U-max-coplanar 6.7e-15
#   Width-outside 1.3e-14  _wide-facet 4e-14  _maxoutside 2.7e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v4):     1     0     0
# - p2(v3):     1     0     1
# - p5(v2):     3     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.4e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     1.25        0     0.25
#
# facet p2 p5 p0 distance=    0
# facet p1 p5 p0 distance=    0
# facet p1 p2 p0 distance=    0
# facet p1 p2 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         3  difference=    3
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.4e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768923096  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1768923096  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# ...
#
# facet p1 p7 p0 distance=    0
# facet p2 p7 p0 distance= -0.25
# facet p2 p1 p0 distance=    0
# facet p2 p1 p7 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         4  difference=    4
#   1:         0         1  difference=    1
#   2:         0         0  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.3e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1807780880  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1807797687  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  3  Error-roundoff 3.4e-15  _one-merge 2.4e-14
#   _near-inside 1.2e-13  Visible-distance 6.7e-15  U-max-coplanar 6.7e-15
#   Width-outside 1.3e-14  _wide-facet 4e-14  _maxoutside 2.7e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v4):     1     0     0
# - p2(v3):     1     0     1
# - p5(v2):     3     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.4e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     1.25        0     0.25
#
# facet p2 p5 p0 distance=    0
# facet p1 p5 p0 distance=    0
# facet p1 p2 p0 distance=    0
# facet p1 p2 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         3  difference=    3
#   1:         0         0  difference=    0
#   2:         0         1  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.4e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(3) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1807831301  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1807898529  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1807932143  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1807948950  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1807965757  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(3) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1807982564  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1807999371  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  3  Error-roundoff 4e-15  _one-merge 2.8e-14  _near-inside 1.4e-13
#   Visible-distance 8.1e-15  U-max-coplanar 8.1e-15  Width-outside 1.6e-14
#   _wide-facet 4.8e-14  _maxoutside 3.2e-14
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v4):     1     1     0
# - p5(v3):     2     3     0
# - p2(v2):     2     0     0
# - p0(v1):     0     1     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     1.25     1.25        0
#
# facet p5 p2 p0 distance=    0
# facet p1 p2 p0 distance=    0
# facet p1 p5 p0 distance=    0
# facet p1 p5 p2 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         2  difference=    2
#   1:         0         3  difference=    3
#   2:         0         0  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1808016178  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1808083406  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(1) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1808083406  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(3) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1808100213  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1808100213  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _maxoutside  0
#
#   return convex_hull_image(self.image)
# C:\Users\fsalo\mambaforge\envs\outer-segment-analysis\lib\site-packages\skimage\measure\_regionprops.py:395: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1808133827  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width  4  Error-roundoff 4.3e-15  _one-merge 3e-14  _near-inside 1.5e-13
#   Visible-distance 8.5e-15  U-max-coplanar 8.5e-15  Width-outside 1.7e-14
#   _wide-facet 5.1e-14  _maxoutside 3.4e-14
#
# precision problems (corrected unless 'Q0' or an error)
#       1 degenerate hyperplanes recomputed with gaussian elimination
#       1 nearly singular or axis-parallel hyperplanes
#       1 zero divisors during back substitute
#       1 zero divisors during gaussian elimination
#
# The input to qhull appears to be less than 3 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p2(v4):     1     0     0
# - p1(v3):     0     1     0
# - p8(v2):     4     0     0
# - p0(v1):     0     0     0
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.3e-15.  The center point, facets and distances
# to the center point are as follows:
#
# center point     1.25     0.25        0
#
# facet p1 p8 p0 distance=    0
# facet p2 p8 p0 distance= -0.25
# facet p2 p1 p0 distance=    0
# facet p2 p1 p8 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:         0         4  difference=    4
#   1:         0         1  difference=    1
#   2:         0         0  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.3e-15.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   return convex_hull_image(self.image)

# %%
# Concatenate the dataframe
features_porespy = pd.concat(features_porespy)

# %%
# Show the features
features_porespy
# Out:
#      label  surface_area  volume  bbox_volume  convex_volume  sphericity  \
# 0        1    820.528198   833.0         3456           1525    0.521780
# 1        2    417.350677   754.0         1254            865    0.959910
# 2        3    209.240112   226.0          416            274    0.857521
# 3        4    227.670990   237.0          480            284    0.813471
# 4        5     80.413963    25.0           72             33    0.514177
# ..     ...           ...     ...          ...            ...         ...
# 173    174   1265.061035  1224.0         6732           3094    0.437415
# 174    175    978.182373  1019.0         5250           2200    0.500626
# 175    176     70.511078    44.0           90             54    0.854795
# 176    177    638.787354   473.0         3465           1333    0.459588
# 177    178      6.928203    10.0           10              0    3.239889
#
#      solidity  perimeter_2d  major_axis_length_2d  minor_axis_length_2d
# 0    0.546230     57.153073             27.467594              6.307231
# 1    0.871676     27.791138             10.665223              6.330765
# 2    0.824818     19.421265              7.894590              4.064904
# 3    0.834507     19.421265              8.565180              3.459917
# 4    0.757576      8.599912              3.126944              2.309401
# ..        ...           ...                   ...                   ...
# 173  0.395604     93.084047             25.469903             16.027167
# 174  0.463182     67.974426             28.804014             11.992024
# 175  0.814815     12.392149              5.022825              2.508233
# 176  0.354839     59.374514             28.204786              8.149047
# 177       inf      4.577636              2.000000              0.000000
#
# [18708 rows x 10 columns]

# %%
features_porespy.to_csv("../../measurements/wt-postnatal-development/01-b-feature-extraction-porespy.csv", index = False)
