# %% [markdown]
# ## The OS numbers between of Cpfl1 are checked for significance

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.stats.multicomp as mc

from scipy.stats import ttest_ind

# %%
path = "../../measurements/cpfl/"
measurements = pd.read_csv(path + "05-measurements-filtered-5-and-95-percentiles.csv")
measurements
# Out:
#       label  age  image_id genotype  maximum        mean      median  minimum  \
# 0         1    8         0     cpfl    250.0  189.793103  184.144531    157.0
# 1         2    8         0     cpfl    334.0  207.273684  202.871094    133.0
# 2         4    8         0     cpfl    262.0  214.904762  215.355469    175.0
# 3         5    8         0     cpfl    311.0  195.171429  190.386719    118.0
# 4         6    8         0     cpfl    355.0  219.354167  215.355469    147.0
# ...     ...  ...       ...      ...      ...         ...         ...      ...
# 5226    176   70        39       wt    437.0  228.476298  219.855469    118.0
# 5227    177   70        39       wt   1542.0  485.858939  412.605469    137.0
# 5228    178   70        39       wt    416.0  224.548673  213.832031    127.0
# 5229    180   70        39       wt    481.0  251.469466  237.925781    145.0
# 5230    181   70        39       wt    289.0  198.567568  195.761719    131.0
#
#            sigma        sum  ...  equivalent_spherical_perimeter_rescaled  \
# 0      20.305487     5504.0  ...                                14.744113
# 1      42.706679    19691.0  ...                                32.521386
# 2      27.285353     4513.0  ...                                11.889571
# 3      36.997206     6831.0  ...                                16.713421
# 4      47.335750    21058.0  ...                                32.749208
# ...          ...        ...  ...                                      ...
# 5226   59.914239   101215.0  ...                                90.772814
# 5227  265.029227  1043625.0  ...                               260.041601
# 5228   62.839505    25374.0  ...                                36.509477
# 5229   64.019970    65885.0  ...                                63.956915
# 5230   37.774051    14694.0  ...                                27.532213
#
#       equivalent_spherical_radius_rescaled  feret_diameter_rescaled  \
# 0                                 0.615610                 1.480172
# 1                                 0.914283                 2.624064
# 2                                 0.552814                 1.370373
# 3                                 0.655434                 1.678357
# 4                                 0.917480                 2.068209
# ...                                    ...                      ...
# 5226                              1.527475                 5.732681
# 5227                              2.585340                 9.158631
# 5228                              0.968722                 2.261000
# 5229                              1.282154                 4.579315
# 5230                              0.841234                 2.093279
#
#       perimeter_2d_rescaled  major_axis_length_2d_rescaled  \
# 0                  2.957153                       0.976660
# 1                  4.973873                       2.127172
# 2                  2.957153                       0.976660
# 3                  3.390218                       1.255098
# 4                  5.481241                       1.910113
# ...                     ...                            ...
# 5226              13.307188                       6.005873
# 5227              32.454379                       8.011704
# 5228               5.734924                       1.901773
# 5229              13.771030                       4.629315
# 5230               4.794492                       1.926136
#
#       minor_axis_length_2d_rescaled  surface_area_rescaled  \
# 0                          0.904212               3.881768
# 1                          1.027014               7.095704
# 2                          0.904212               5.174290
# 3                          0.902928               7.379101
# 4                          1.514661              11.022045
# ...                             ...                    ...
# 5226                       1.731845              45.719796
# 5227                       7.033195             160.768595
# 5228                       1.715924              15.687029
# 5229                       2.203200              35.317111
# 5230                       1.040501               8.369222
#
#       bbox_volume_rescaled  convex_volume_rescaled  volume_rescaled
# 0                 1.516422                1.078345         0.977250
# 1                 4.852550                3.572016         3.201335
# 2                 1.516422                0.943551         0.707664
# 3                 2.426275                1.381629         1.179439
# 4                 6.065688                3.774206         3.235034
# ...                    ...                     ...              ...
# 5226             55.197761               20.994020        14.928332
# 5227            300.992921              132.366793        72.383878
# 5228              8.491963                4.414473         3.807904
# 5229             35.383180               15.063125         8.828946
# 5230              4.245982                2.931749         2.493672
#
# [5231 rows x 31 columns]

# %% [markdown]
# ### Preparing the dataset

# %%
number_of_labels = measurements.groupby("image_id", as_index=False)["label"].size()
number_of_labels.rename(columns={'size': 'label'}, inplace=True)
age = measurements.groupby("image_id", as_index=False)["age", "genotype"].max()
number_of_labels = pd.merge(number_of_labels, age)
number_of_labels
# Out:
# C:\Users\fsalo\AppData\Local\Temp\ipykernel_5608\3395052209.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   age = measurements.groupby("image_id", as_index=False)["age", "genotype"].max()
#     image_id  label  age genotype
# 0          0     99    8     cpfl
# 1          1     93    8     cpfl
# 2          2     62    8     cpfl
# 3          3    290   14     cpfl
# 4          4    216   14     cpfl
# 5          5    135   14     cpfl
# 6          6    145   20     cpfl
# 7          7    164   20     cpfl
# 8          8    155   20     cpfl
# 9          9     33  245     cpfl
# 10        10     10  245     cpfl
# 11        11     19  245     cpfl
# 12        12      6  245     cpfl
# 13        13    114   30     cpfl
# 14        14     93   30     cpfl
# 15        15    159   30     cpfl
# 16        16     36   70     cpfl
# 17        17     55   70     cpfl
# 18        18     64   70     cpfl
# 19        19     96    8       wt
# 20        20    129    8       wt
# 21        21    118    8       wt
# 22        22    103    8       wt
# 23        23     57   14       wt
# 24        24    207   14       wt
# 25        25    160   14       wt
# 26        26    265   14       wt
# 27        27    144   20       wt
# 28        28    140   20       wt
# 29        29    180   20       wt
# 30        30    144   20       wt
# 31        31    260  245       wt
# 32        32    146  245       wt
# 33        33    184  245       wt
# 34        34    118   30       wt
# 35        35    149   30       wt
# 36        36    219   30       wt
# 37        37    224   70       wt
# 38        38    135   70       wt
# 39        39    105   70       wt

# %% [markdown]
# ### Test for significance
#
# - different genotypes are compared within their respective age
# - Welsh's t test is used
# - based on the plot:
#     - alternative hypothesis: OS number (Cpfl1) < OS number (WT)
#     - Null hypothesis: OS number (Cpfl1) >= OS number (WT)

# %%
ages = [8, 14, 20, 30, 70, 245]

test_results = []

for i, postnatal_age in enumerate(ages):
    
    age_filtered = measurements[measurements["age"] == postnatal_age]
    
    number_of_labels_cpfl = age_filtered[age_filtered["genotype"] == "cpfl"]["label"]
    number_of_labels_wt = age_filtered[age_filtered["genotype"] == "wt"]["label"]
    
    t_statistic, p_value = ttest_ind(number_of_labels_wt,
                                     number_of_labels_cpfl,
                                     equal_var=False,
                                     alternative="greater")
    
    test_results.append({"age": postnatal_age, "p_value": p_value})
    
test_results = pd.DataFrame(test_results)
test_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 test_results = []
#       5 for i, postnatal_age in enumerate(ages):
# ----> 7     age_filtered = number_of_labels[number_of_labels["age"] == postnatal_age]
#       9     number_of_labels_cpfl = age_filtered[age_filtered["genotype"] == "cpfl"]["label"]
#      10     number_of_labels_wt = age_filtered[age_filtered["genotype"] == "wt"]["label"]
#
# NameError: name 'number_of_labels' is not defined

# %% [markdown]
# ### ANOVA test for Cpfl1 OS number alone

# %%
#import custom functions
import sys
sys.path.append("../../../../../../01_python_definitions")
from fluorescent_microscopy_analysis import tukey_test

# %%
number_of_labels_cpfl = number_of_labels[number_of_labels["genotype"] == "cpfl"]
number_of_labels_cpfl
# Out:
#     image_id  label  age genotype
# 0          0     99    8     cpfl
# 1          1     93    8     cpfl
# 2          2     62    8     cpfl
# 3          3    290   14     cpfl
# 4          4    216   14     cpfl
# 5          5    135   14     cpfl
# 6          6    145   20     cpfl
# 7          7    164   20     cpfl
# 8          8    155   20     cpfl
# 9          9     33  245     cpfl
# 10        10     10  245     cpfl
# 11        11     19  245     cpfl
# 12        12      6  245     cpfl
# 13        13    114   30     cpfl
# 14        14     93   30     cpfl
# 15        15    159   30     cpfl
# 16        16     36   70     cpfl
# 17        17     55   70     cpfl
# 18        18     64   70     cpfl

# %%
f, p, tukey = tukey_test(number_of_labels_cpfl, feature="label")
tukey
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
